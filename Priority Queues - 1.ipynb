# %%
#Remove Min
class PriorityQueueNode:
    def __init__(self,ele,priority):
        self.ele = ele
        self.priority = priority
        
class PriorityQueue:
    def __init__(self):
        self.pq = []
    
    def isEmpty(self):
        return self.getSize() == 0
    
    def getSize(self):
        return len(self.pq)

    def getMin(self):
        if self.isEmpty():
            return None
        return self.pq[0].ele
    
    def __percolateUp(self):
        childIndex = self.getSize() - 1
        while childIndex > 0:
            parentIndex = (childIndex-1)//2
            
            if self.pq[parentIndex].priority > self.pq[childIndex].priority:
                self.pq[parentIndex],self.pq[childIndex] = self.pq[childIndex],self.pq[parentIndex]
                childIndex = parentIndex
            else:
                break
        
    def insert(self,ele,priority):
        pqNode = PriorityQueueNode(ele,priority)
        self.pq.append(pqNode)
        self.__percolateUp()
        
    def __percolateDown(self):
        #maintaining variable parentIndex, leftchildindex, rightchildindex
        parentIndex = 0
        leftchildindex = 2 * parentIndex + 1
        rightchildindex = 2 * parentIndex + 2
        #loop will run till leftchildindex is less then size of pq
        while leftchildindex < self.getSize():
            #creating new variable minIndex and assigning parentIndex to it
            minIndex = parentIndex
            #checking if left child priority is less than parent priority and assigning leftchildindex to minIndex
            if self.pq[minIndex].priority > self.pq[leftchildindex].priority:
                minIndex = leftchildindex
            #checking if right child priority is less than parent priority and assigning rightchildindex to minIndex    
            if rightchildindex < self.getSize() and self.pq[minIndex].priority > self.pq[rightchildindex].priority:
                minIndex = rightchildindex
            #when minIndex == parentIndex then breaking loop
            if minIndex == parentIndex:
                break
            #swapping element in pq list for parentIndex and minIndex    
            self.pq[parentIndex],self.pq[minIndex] = self.pq[minIndex],self.pq[parentIndex]
            parentIndex = minIndex
            leftchildindex = 2 * parentIndex + 1
            rightchildindex = 2 * parentIndex + 2
        
    def removeMin(self):
        #checking if pq is empty then return none
        if self.isEmpty():
            return None
        #storing ele of 0 index in ans and returning it
        ans = self.pq[0].ele
        #filling 0 index with last element of pq
        self.pq[0] = self.pq[self.getSize() - 1]
        #popping the last element of pq
        self.pq.pop()
        #call __percolateDown()
        self.__percolateDown()
        return ans
        
myPq = PriorityQueue()
curr_input = [int(ele) for ele in input().split()]
choice = curr_input[0]
i=1
while choice != -1:
    if choice == 1:
        element = curr_input[i]
        i+=1
        myPq.insert(element,element)
    elif choice == 2:
        print(myPq.getMin())
    elif choice == 3:
        print(myPq.removeMin())
    elif choice == 4:
        print(myPq.getSize())
    elif choice == 5:
        if myPq.isEmpty():
            print('true')
        else:
            print('false')
        break
    else:
        pass
    choice = curr_input[i]
    i+=1
# Out:
# 1 3 1 4 1 63 1 21 1 9 2 3 1 7 2 2 2 3 3 3 -1
# 3
# 3
# 4
# 4
# 4
# 4
# 7
# 9

# %%
#Max Priority Queue
class PriorityQueueNode:
    #creating class which has 2 things element and priority of that element
    def __init__(self,ele,priority):
        self.ele = ele
        self.priority = priority
        
class PriorityQueue:
    #creating class which stores priority queue node in a list
    def __init__(self):
        self.pq = []
    #checking if pq list is empty
    def isEmpty(self):
        return self.getSize() == 0
    #checking length of pq list
    def getSize(self):
        return len(self.pq)
    #getting max value from pq list which always present at 0 index 
    def getMax(self):
        if self.isEmpty():
            return None
        return self.pq[0].ele
    
    def __percolateUp(self):
        #saving last element index of list pq in childIndex
        childIndex = self.getSize() - 1
        #loop will run till childIndex is greater than 0
        while childIndex > 0:
            #finding value of parentIndex using childIndex
            parentIndex = (childIndex - 1) // 2
            #checking priority of childindex is greater than parent index and swapping it
            #assiging parentIndex to childIndex
            #else breaking the loop
            if self.pq[childIndex].priority > self.pq[parentIndex].priority:
                self.pq[childIndex], self.pq[parentIndex] = self.pq[parentIndex], self.pq[childIndex]
                childIndex = parentIndex
            else:
                break
      
    def insert(self,ele,priority):
        #creating priority queue node using class PriorityQueueNode
        pqNode = PriorityQueueNode(ele, priority)
        #appending pqNode to pq list
        self.pq.append(pqNode)
        #calling __percolateUp()
        self.__percolateUp()
        
    def __percolateDown(self):
        #maintaining variable parentIndex, leftchildindex, rightchildindex
        parentIndex = 0
        leftChildIndex = 2 * parentIndex + 1
        rightChildIndex = 2 * parentIndex + 2
        #loop will run till leftchildindex is less then size of pq
        while leftChildIndex < self.getSize():
            #creating new variable minIndex and assigning parentIndex to it
            maxIndex = parentIndex
            #checking if left child priority is more than parent priority and assigning leftchildindex to maxIndex
            if self.pq[maxIndex].priority < self.pq[leftChildIndex].priority:
                maxIndex = leftChildIndex
            #checking if right child priority is more than parent priority and assigning rightchildindex to maxIndex    
            if rightChildIndex < self.getSize() and self.pq[maxIndex].priority < self.pq[rightChildIndex].priority:
                maxIndex = rightChildIndex
            #when maxIndex == parentIndex then breaking loop    
            if maxIndex == parentIndex:
                break
            #swapping element in pq list for parentIndex and maxIndex     
            self.pq[maxIndex], self.pq[parentIndex] = self.pq[parentIndex], self.pq[maxIndex]
            parentIndex = maxIndex
            leftChildIndex = 2 * parentIndex + 1
            rightChildIndex = 2 * parentIndex + 2
        
    def removeMax(self):
        #checking if pq is empty then return none
        if self.isEmpty():
            return None
        #storing ele of 0 index in ans and returning it
        ans = self.pq[0].ele
        #filling 0 index with last element of pq
        self.pq[0] = self.pq[self.getSize() - 1]
        #popping the last element of pq
        self.pq.pop()
        #call __percolateDown()
        self.__percolateDown()
        return ans
        
myPq = PriorityQueue()
curr_input = [int(ele) for ele in input().split()]
choice = curr_input[0]
i=1
while choice != -1:
    if choice == 1:
        element = curr_input[i]
        i+=1
        myPq.insert(element,element)
    elif choice == 2:
        print(myPq.getMax())
    elif choice == 3:
        print(myPq.removeMax())
    elif choice == 4:
        print(myPq.getSize())
    elif choice == 5:
        if myPq.isEmpty():
            print('true')
        else:
            print('false')
        break
    else:
        pass
    choice = curr_input[i]
    i+=1
# Out:
# 1 3 1 4 1 63 1 21 1 9 2 3 1 7 2 2 2 3 -1
# 63
# 63
# 21
# 21
# 21
# 21
