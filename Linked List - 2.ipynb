# %%
#Reverse LL (Recursive)
from sys import setrecursionlimit
setrecursionlimit(10 ** 6)

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None

def reverseLinkedListRec(head):
    #first we check the base if head is none then return
    if head is None or head.next is None:
        return head
    #assuming induction hypothesis printreverse will give correct element
    out = reverseLinkedListRec(head.next)
    #put first element at end
    head.next.next = head
    head.next = None
    return out

#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0 :
    
    head = takeInput()

    newHead = reverseLinkedListRec(head)
    printLinkedList(newHead)

    t = t - 1
# Out:
# 1
# 1 2 3 4 5 -1
# 5 4 3 2 1

# %%
#Reverse LL (Iterative)
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None

def reverse(head):
    #first we check the base if head is none then return
    if head is None:
        return head
    #then we take 2 variable prev and curr
    prev = None
    curr = head
    #looping through list till curr is not None
    while curr is not None:
        #Assigning nextHead to curr.next
        #Assigning curr.next to prev
        #Assigning prev to curr
        #Assigning curr to nextHead
        nextHead = curr.next
        curr.next = prev
        prev = curr
        curr = nextHead
        
    return prev

#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0 :
    
    head = takeInput()

    newHead = reverse(head)
    printLinkedList(newHead)

    t = t - 1
# Out:
# 1
# 1 2 3 4 5 -1
# 5 4 3 2 1

# %%
#Midpoint of Linked list
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None
        
        
def midPoint(head):
    #first we check the base case if head is None then we return
    if head is None:
        return
    #we create two variable slow and fast both assigned to head
    slow = head
    fast = head
    #then for even and odd Length of Linked list we should check fast.next or fast.next.next to null 
    while fast.next != None and fast.next.next != None:
        slow = slow.next
        fast = fast.next.next
    return slow

#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0 :
    
    head = takeInput()

    mid = midPoint(head)
    
    if mid is not None:
        print(mid.data)

    t = t - 1
# Out:
# 1
# 1 2 3 4 5 -1
# 3

# %%
#Code : Merge two sorted LL
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None
        
def mergeTwoSortedLinkedLists(head1, head2):
    #first we check the base cases
    #if both head is none then we simply return
    if head1 is None and head2 is None:
        return
    #if one head is none then we simply return the other head
    if head1 is None:
        return head2
    
    if head2 is None:
        return head1
    #we will take two variable and assign them with none
    newHead = None
    newTail = None
    #first we check which head is smaller
    #smaller head is assigned to newHead and newTail
    #smaller head is aasigned to head.next
    if head1.data < head2.data:
        newHead = head1
        newTail = head1
        head1 = head1.next
    else:
        newHead = head2
        newTail = head2
        head2 = head2.next
    #then loop through both linked list using while check head1 and head2 is not none    
    while head1 is not None and head2 is not None:
        #if head1.data is small then we assign newTail.next to head1
        #newTail assigned to head1.next
        #head1 is assignedt ot head1.next
        if head1.data < head2.data:
            newTail.next = head1
            newTail = newTail.next
            head1 = head1.next
        else:
            newTail.next = head2
            newTail = newTail.next
            head2 = head2.next
    #if head1 linked is greater in length of head2 linked list then we assign newTail.next to head1 which has remain elements
    if head1 is not None:
        newTail.next = head1
        
    if head2 is not None:
        newTail.next = head2
    #we return newHead    
    return newHead

#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0 :
    head1 = takeInput()
    head2 = takeInput()
    newHead = mergeTwoSortedLinkedLists(head1, head2)
    printLinkedList(newHead)
    t = t - 1
# Out:
# 1
# 1 3 5 -1
# 2 4 6 -1
# 1 2 3 4 5 6

# %%
#Code : Merge Sort
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None
        
def mergeTwoSortedLinkedLists(head1, head2):
    #first we check the base cases
    #if both head is none then we simply return
    if head1 is None and head2 is None:
        return
    #if one head is none then we simply return the other head
    if head1 is None:
        return head2
    
    if head2 is None:
        return head1
    #we will take two variable and assign them with none
    newHead = None
    newTail = None
    #first we check which head is smaller
    #smaller head is assigned to newHead and newTail
    #smaller head is aasigned to head.next
    if head1.data < head2.data:
        newHead = head1
        newTail = head1
        head1 = head1.next
    else:
        newHead = head2
        newTail = head2
        head2 = head2.next
    #then loop through both linked list using while check head1 and head2 is not none    
    while head1 is not None and head2 is not None:
        #if head1.data is small then we assign newTail.next to head1
        #newTail assigned to head1.next
        #head1 is assignedt ot head1.next
        if head1.data < head2.data:
            newTail.next = head1
            newTail = newTail.next
            head1 = head1.next
        else:
            newTail.next = head2
            newTail = newTail.next
            head2 = head2.next
    #if head1 linked is greater in length of head2 linked list then we assign newTail.next to head1 which has remain elements
    if head1 is not None:
        newTail.next = head1
        
    if head2 is not None:
        newTail.next = head2
    #we return newHead    
    return newHead

def midPoint(head):
    #first we check the base case if head is None then we return
    if head is None:
        return
    #we create two variable slow and fast both assigned to head
    slow = head
    fast = head
    #then for even and odd Length of Linked list we should check fast.next or fast.next.next to null 
    while fast.next != None and fast.next.next != None:
        slow = slow.next
        fast = fast.next.next
    return slow

def mergeSort(head):
    #first we write the base case 
    if head is None or head.next is None:
        return head
    #we find mid point of linked list
    midElement = midPoint(head)
    #then we create second part head by using midElement.next
    part2 = midElement.next
    #then we will break the linked list by making midElement = None
    midElement.next = None
    part1 = head
    #Assuming induction hypothesis mergeSort will give sorted list for both part of linked list 
    head1 = mergeSort(part1)
    head2 = mergeSort(part2)
    #then we save the output of mergeSort recusrsion as head1 and head2
    #passing head1 and head2 to the mergeSorted function where it merge 2 sorted linked list 
    newHeadSorted = mergeTwoSortedLinkedLists(head1, head2)
    
    return newHeadSorted
    

#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0 :
    head = takeInput()
    newHead = mergeSort(head)
    printLinkedList(newHead)
    t = t - 1
# Out:
# 1
# 1 3 5 2 6 4 -1
# 1 2 3 4 5 6

# %%
#Find a node in LL (recursive)
from sys import setrecursionlimit
setrecursionlimit(10 ** 6)
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None
        
def findNodeRec(head, n):
    #first base case if head is None then return -1
    if head is None:
        return -1
    #if head.data == n then return 0
    if head.data == n:
        return 0
    #Assign count = 1
    count = 1
    #Assuming induction hypothesis function will give correct index
    out = findNodeRec(head.next, n)
    #checking if recurssion output is -1 then return -1
    if out == -1:
        return out
    #return count + out
    else:
        return count + out


#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0 :
    
    head = takeInput()
    n = int(input())
    print(findNodeRec(head, n))

    t = t - 1
# Out:
# 1
# 1 2 3 4 5 -1
# 6
# 3

# %%
#Even after Odd LinkedList
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None

def evenAfterOdd(head):
    #first we check the base case if head is none then we return
    if head is None:
        return
    #then we use for variables assign them to none
    oddHead = None
    oddTail = None
    evenHead = None
    evenTail = None
    #then we traverse through list while head is none
    while head is not None:
        #we check for even and odd condition
        if head.data % 2 != 0:
            #we always check if oddHead or evenHead is none then we assign them with head
            #else we assign tail.next to head and tail to head
            if oddHead is None:
                oddHead = head
                oddTail = head
            else:
                oddTail.next = head
                oddTail = head
        else:
            if evenHead is None:
                evenHead = head
                evenTail = head
            else:
                evenTail.next = head
                evenTail = head
        #then we had to make tail.next of even and odd ll to none so we check this condition        
        if head.next is None and evenTail is not None and oddTail is not None:
            evenTail.next = None
            oddTail.next = None
            
        head = head.next
        
    finalHead = None
    #then we check if oddhead is none means there is no odd numn=ber is linked list so we return the evenhead
    if oddHead is None:
        finalHead = evenHead
    else:
        #else we return the odd head
        oddTail.next = evenHead
        finalHead = oddHead
    
    return finalHead
    
#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0 :
    head = takeInput()
    newHead = evenAfterOdd(head)
    printLinkedList(newHead)
    t = t - 1
# Out:
# 1
# 1 2 3 5 4 -1
# 1 3 5 2 4

# %%
#Delete every N nodes
from sys import setrecursionlimit
setrecursionlimit(10 ** 6)
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None
        
def skipMdeleteN(head, M, N):
    #base case if head is none or head.next is none then return head
    if head is None or head.next is None:
        return head
    #according to condition if N = 0 means we have delete 0 elements after every M elements so simply return the linked list
    if N == 0:
        return head
    #accordint to condition we have to delete N elements after every M = 0 elements means deleting all elements
    if M == 0:
        return
    #take 2 variables t1 = head and t2 = none
    t1 = head
    t2 = None
    #using for loop 1 to M + 1 means if M = 2 then i will 1 and then 2
    for i in range(1,M +1,1):
        #assigning t2 to t1
        #t1.next to t1
        t2 = t1
        t1 =t1.next
    #using for loop 1 to N + 1 means if N = 2 then i will 1 and then 2
    for j in range(1,N+1,1):
        #checking first if t is not none
        if t1 != None:
            #then assigning t1.next to t1
            t1 = t1.next
    #at last joining t2.next to t1 means if we have 1 2 3 4 5 -1 as LL and t2 is at 2 and t1 is at 5 then 2 is joined to
    #2.next = 5
    t2.next = t1
    #Assuming induction hypothesis that recursiion will give skip deleted node LL for t1
    skipMdeleteN(t1, M, N)
    return head
                
#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1):
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0:
    head = takeInput()
    m_n = list(int(ele) for ele in input().split())
    
    m = int(m_n[0])
    n = int(m_n[1])
    
    newHead = skipMdeleteN(head,m,n)
    printLinkedList(newHead)
    t = t - 1
# Out:
# 1
# -1
# 2 2

# %%
#Swap two Nodes of LL
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None
        
def swapNodes(head, i, j):
    #first we check base condition if i equal to j meant we dont have to swap simply return head
    if i == j:
        return head
    #we maintain 2 variable curr = head and prev = none
    curr = head
    prev = None
    #we maintain 4 variable in c1 which holds ith variable and p1 holds previos of ith variable
    #similarlyy c2 holds jth variable and p2 holds previous of jth variable
    p1 = None
    c1 = None
    p2 = None
    c2 = None
    #pos is to maintain counter for while loop
    pos = 0
    
    while curr is not None:
        #if pos == i then we update p1 with prev and c1 with curr
        if pos == i:
            p1 = prev
            c1 = curr
        #if pos == j then we update p2 with prev and c2 with curr
        elif pos == j:
            p2 = prev
            c2 = curr
        #updating prev with curr and curr with curr.next nad pos = pos + 1    
        prev = curr
        curr = curr.next
        pos = pos + 1
    #checking if p1 is not none
    if p1 is not None:
        #assigning p1.next to c2. Means in 1 2 3 4 5 -1 if p1 = 2 and c2 = 4 then 2.next = 4
        p1.next = c2
    else:
        #if p1 is none means i == 0 so we need to update head with c2
        head = c2
     #checking if p2 is not none   
    if p2 is not None:
        #assigning p2.next to c1. Means in 1 2 3 4 5 -1 if p2 = 3 and c1 = 2 then 3.next = 2
        p2.next = c1
    else:
        #if p2 is none means j == 0 so we need to update head with c1
        head = c1
    #maintaining temp variable to c2.next means in 1 2 3 4 5 -1 if c2 = 4 tehn temp = 4.next = 5
    #updating c2.next = c1.next means in 1 2 3 4 5 -1 if c2 = 4 and c1 = 2 then c2.next = 2.next = 3
    temp = c2.next
    c2.next = c1.next
    #updating c1.next = temp
    c1.next = temp
    
    return head

#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1):
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0:
    head = takeInput()
    i_j = list(int(ele) for ele in input().split())
    
    i = int(i_j[0])
    j = int(i_j[1])
    
    newHead = swapNodes(head,i,j)
    printLinkedList(newHead)
    t = t - 1
# Out:
# 1
# 1 2 3 4 5 -1
# 4 3
# 1 2 3 5 4

# %%
#kReverse
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None

def kReverse(head, k):
    #We check the base case
    if head is None:
        return head
    #if k is 0 or k is 1 then return head
    if k == 0 or k == 1:
        return head
    #we need 4 variables cout, curr, nextNode, prev
    #starting count = 0
    #staring curr = head
    #starting nextNode = None
    #starting prev = None
    count = 0
    curr = head
    nextNode = None
    prev = None
    #checking if curr is not none and count is less than k
    while curr is not None and count < k:
        #nextNode = curr.next means in 1 2 3 4 5 -1 if curr = 1 then nextNode = 2
        nextNode = curr.next
        #curr.next = prev means in 1 2 3 4 5 -1 if prev = None then curr.next = None
        curr.next = prev
        #prev = curr means in 1 2 3 4 5 -1 if curr = 1 then prev = 1
        prev = curr
        #curr = nextNode means in 1 2 3 4 5 -1 if nextNode = 2 then curr = 2
        curr = nextNode
        count = count + 1
    #checking if nextNode is not None    
    if nextNode is not None:
        #Assuming induction hypothesis that function will kReverse rest of linked list
        #Also making connection head.next = prev which is return by recurssion
        head.next = kReverse(nextNode,k)
             
    return prev
             
#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(input())

while t > 0 :
    head = takeInput()
    k = int(input())
    newHead = kReverse(head,k)
    printLinkedList(newHead)
    t = t - 1
# Out:
# 1
# 1 2 3 4 5 -1
# 2
# 2 1 4 3 5

# %%
#Bubble Sort (Iterative) LinkedList
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data):
        self.data = data
        self.next = None

def lengthLL(headLL):
    #maintaining variable count starting at 
    count = 0
    #till head is not none
    while headLL is not None:
        #moving head to head.next
        headLL = headLL.next
        count = count + 1
    #returning count
    return count


def bubbleSort(head):
    #checking base condition if head or head.next is none then return head
    if head is None or head.next is None:
        return head
    
    headLL = head
    #calculating length of inked list
    count = lengthLL(headLL)
    #using for loop from range 0 to length - 1
    for i in range(0,count-1,1):
        #maintaining 3 variables curr, nextNode and prev
        #curr = head
        #nextNode = nextNode.next
        #prev = None
        curr = head
        nextNode = curr.next
        prev = None
        #trversing through while loop
        while nextNode is not None:
            #checking if current element is greater then nex element
            if curr.data > nextNode.data:
                #if prev is None means current element is the head of linked list
                if prev == None:
                    #so prev = curr.next means in 2 1 3 4 5 -1 if prev = none and curr = 2 then prev = 2.next = 1
                    prev = curr.next
                    #so nextNode = nextNode.next means in 2 1 3 4 5 -1 if nextNode = 1 then nextNode.next = 3
                    nextNode = nextNode.next 
                    #prev.next = curr means in 2 1 3 4 5 -1 prev = 1 then prev.next = 2
                    prev.next = curr
                    #curr.next = nextNode means in 2 1 3 4 5 -1 nextNode = 3 then 2.next = 3
                    curr.next = nextNode
                    #at last we change our head to prev means 1
                    head = prev
                else:
                    #if prev is not None
                    #creating a temp  = nextNode
                    temp = nextNode
                    #nextnode = nextnode.next means 3 2 1 4 5 -1 nextNode = 1 and nextnode.next = 4
                    nextNode = nextNode.next
                    #prev.next = curr.next means in 3 2 1 4 5 -1 3.next = 2.next = 1
                    prev.next = curr.next
                    #prev = temp means in in 3 2 1 4 5 -1 prev = 1 
                    prev = temp
                    #means in 3 2 1 4 5 -1 1.next = 2
                    temp.next = curr
                    #means in 3 2 1 4 5 -1 2.next = 4
                    curr.next = nextNode
            else:
                prev = curr
                curr = nextNode
                nextNode = nextNode.next
    return head
    
#Taking Input Using Fast I/O
def takeInput():
    head = None
    tail = None

    datas = list(int(ele) for ele in input().split())

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i = i + 1

    return head

def printLinkedList(head):

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
head = takeInput()
newHead = bubbleSort(head)
printLinkedList(newHead)
# Out:
# 2 1 6 5 4 3
# 1 2 3 4 5 6
