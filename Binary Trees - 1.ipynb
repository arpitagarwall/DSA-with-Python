# %%
#Sum Of Nodes
from sys import setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

#Following the structure used for Binary Tree
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def getSum(root):
    #base case if root is None
    if root == None:
        return 0
    #Assuming induction hypothesis will give sum of left side root
    left = getSum(root.left)
    #Assuming induction hypothesis will give sum of right side root
    right = getSum(root.right)
    #returning and adding root.data + left and right
    return root.data + left + right

#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(int(ele) for ele in input().split())
    start = 0

    length = len(levelOrder)

    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()
print(getSum(root))
# Out:
# 2 3 4 6 -1 -1 -1 -1 -1
# 15

# %%
#Preorder Binary Tree
from sys import setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

# Following the structure used for Binary Tree
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


def preOrder(root):
    #base case if root is none then return
    if root == None:
        return
    #print root.data with end statement 
    print(root.data, end = " ")
    #Asuuming induction hypothesis will give root.data for left side node
    preOrder(root.left)
    #Assuming induction hypothesis will give root.data for right side node
    preOrder(root.right)


#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(int(ele) for ele in input().split())
    start = 0

    length = len(levelOrder)

    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()
preOrder(root)
# Out:
# 1 2 3 4 5 6 7 -1 -1 -1 -1 -1 -1 -1 -1
# 1 2 4 5 3 6 7

# %%
#Postorder Binary Tree
from sys import setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

#Following the structure used for Binary Tree
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def postOrder(root):
    #base case if root is none then return
    if root == None:
        return
    #Assuming induction hypothesis will give root.data for left side node
    postOrder(root.left)
    #Assuming induction hypothesis will give root.data for right side node
    postOrder(root.right)
    #print root.data with end statement 
    print(root.data, end = " ")
    
    
#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(int(ele) for ele in input().split())
    start = 0

    length = len(levelOrder)

    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()
postOrder(root)
# Out:
# 5 6 10 2 3 -1 -1 -1 -1 -1 9 -1 -1
# 2 9 3 6 10 5

# %%
#Nodes Greater Than X
from sys import setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

#Following is the structure used to represent the Binary Tree Node
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def countNodesGreaterThanX(root, x):
    #checking base 
    if root == None:
        return 0
    #Assuming induction hypothesis will give coorect count of nodes greater than X
    countLeft = countNodesGreaterThanX(root.left, x)
    countRight = countNodesGreaterThanX(root.right, x)
    #checking in return statement if root.data > x then adding 1 to the ouput else only givivng output
    return 1 + countLeft + countRight if root.data > x else countLeft + countRight
    

#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(int(ele) for ele in input().split())
    start = 0

    length = len(levelOrder)

    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()
x = int(input())

count = countNodesGreaterThanX(root, x)
print(count)
# Out:
# 5 6 10 2 3 -1 -1 -1 -1 -1 9 -1 -1
# 5
# 3

# %%
#Height Of Tree
from sys import setrecursionlimit
import queue

setrecursionlimit(10 ** 6)


#Following is the structure used to represent the Binary Tree Node
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None



def height(root):
    #first we check base condition if root is none then return 0
    if root == None:
        return 0
    #assuming induction hypothesis will give hight of left and right tree
    leftHeight = height(root.left)
    rightHeight = height(root.right)
    #if left tree height is more that right tree height than add 1 to left ree hieght or vice versa
    if leftHeight > rightHeight:
        return leftHeight + 1
    else:
        return rightHeight + 1

#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(int(ele) for ele in input().split())
    start = 0
    
    length = len(levelOrder)

    if length == 1 :
        return None
    
    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()

h = height(root)
print(h)
# Out:
# 10 20 30 40 50 -1 -1 -1 -1 -1 -1
# 3

# %%
#Replace Node With Depth

from sys import setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

#Following is the structure used to represent the Binary Tree Node
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def changeToDepthTree(root, level = 0):
    #first check the base case
    if root == None:
        return
    #then we update current root.data = level
    root.data = level
    #assuming induction hypothesis will give correct level for sub trees
    changeToDepthTree(root.left, level + 1)
    changeToDepthTree(root.right, level + 1)
    
    
#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(int(ele) for ele in input().split())
    start = 0
    
    length = len(levelOrder)

    if length == 1:
        return None
    
    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root


def inOrder(root):
    if root is None :
        return 

    inOrder(root.left)
    print(root.data, end = " ")
    inOrder(root.right)
    
# Main
root = takeInput()

changeToDepthTree(root)
inOrder(root)
# Out:
# 2 35 10 2 3 5 2 -1 -1 -1 -1 -1 -1 -1 -1
# 2 1 2 0 2 1 2

# %%
# Is Node Present?
from sys import setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

# Binary TreeNode class
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


def isNodePresent(root, x):
    # check the base case
    if root == None:
        return False
    #check if root.data == x then return true
    if root.data == x:
        return True
    
    # Assuming induction hypothesis will true or false for right and left subtree
    outLeft = isNodePresent(root.left, x)
    outRight = isNodePresent(root.right, x)
    
    #then if left tree output is true return that
    if outLeft is True:
        return outLeft
    #then if right tree output is true return that
    elif outRight is True:
        return outRight
    #else return false
    else:
        return False
    

# To build the tree
def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)

    if length<=0 or levelorder[0]==-1:
        return None

    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)

    while not q.empty():

        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1

        if leftChild != -1:

            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelorder[index]
        index += 1

        if rightChild != -1:

            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root


# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)

x = int(input())

present = isNodePresent(root, x)

if present:
    print('true')
else:
    print('false')
# Out:
# 8 3 10 1 6 -1 14 -1 -1 4 7 13 -1 -1 -1 -1 -1 -1 -1
# 7
# true

# %%
# Nodes without sibling
from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)


#Following is the structure used to represent the Binary Tree Node
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None



def printNodesWithoutSibling(root):
    # first check the base case
    if root == None:
        return
    
    # if root.left is not none and root.right is none then print root.right.data
    if root.left == None and root.right != None:
        print(root.right.data, end = " ")
    # if root.left is none and root.right is not none then print root.left.data
    if root.left != None and root.right == None:
        print(root.left.data, end = " ")
        
    # Assuming induction hypothesis will give all nodes    
    printNodesWithoutSibling(root.left)
    printNodesWithoutSibling(root.right)
    

#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(int(ele) for ele in input().split())
    start = 0
    
    length = len(levelOrder)

    if length == 1 :
        return None
    
    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root


# Main
root = takeInput()
printNodesWithoutSibling(root)
# Out:
# 5 6 10 2 3 -1 -1 -1 -1 -1 9 -1 -1
# 9
